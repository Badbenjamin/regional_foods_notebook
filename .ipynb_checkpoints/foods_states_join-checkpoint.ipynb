# %% [markdown]
# This is a dataset of regional US cuisine that has been scraped from the "List of Regional Dishes of the United States" Wikipedia page (https://en.wikipedia.org/wiki/List_of_regional_dishes_of_the_United_States#City_chicken). Scraped with beautiful soup, (sorta) standardized with Python, and then manually organized to account for hard to deal with data.

# %%
import pandas as pd 
import geopandas as gpd

foods_csv = '/Users/benmccarthy/Development/data_projects/regional_foods/regional_foods_EDITED_FOR_PROJ_4.csv'
foods_df = pd.read_csv(foods_csv)


states_geojson = '/Users/benmccarthy/Development/data_projects/regional_foods/states_geojson.json'
states_gdf = gpd.read_file(states_geojson, engine="pyogrio")
# states_gdf

# foods_df

geographies = []
# iterate thorugh foods, clean data, 
for index, row in foods_df.iterrows():
    # use eval to replace nasty little weird ass quotes
    
    state_list = eval(row['state'].replace("’","'").replace("‘","'").replace('"',"'").replace('”',"'").replace('“',"'"))
    # logic to handle rows without states (only regions, multiple regions, sub-regions) for later date. 
    # if len(state_list) == 0:
    #     print(row['region'])
    #     if row['region'] == 'Multiple':
    #         print(row['sub-region'])
    for state in state_list:
        # how does this filter work? 
        # we are looping through foods, with a nested loop looping through the states array of foods. 
        # state is the state from foods
        # if we find a match in states_gdf (states and geometries gdf) we create an obj with state name and geometry ->
        # and spread the rest of the row from foods_df to the new obj. 
        search = states_gdf[states_gdf['NAME'] == state]
        # else branch for when there is no state or states, replace with states from region?
        # print(len(search))
        if len(search):
            # append to geographies array, which we will turn into our own new df
            
            geographies.append({
                'geometry': search.iloc[0].geometry,
                'state' : state,
                # spread rows
                **row
            })

# %%
foods_with_geographies_gpd = gpd.GeoDataFrame(geographies, crs='4326')
foods_with_geographies_gpd
# geographies_gpd.to_file("/Users/benmccarthy/Development/data_projects/Jupyter.geojson", driver="GeoJSON")
# Out:
#                                               geometry              state  \
# 0    POLYGON ((-109.04522 36.99908, -109.04524 36.9...        ['Arizona']
# 1    MULTIPOLYGON (((-71.94356 41.28668, -71.92680 ...       ['New York']
# 2    MULTIPOLYGON (((-97.13436 27.89633, -97.13360 ...          ['Texas']
# 3    MULTIPOLYGON (((-70.83204 41.60650, -70.82373 ...  ['Massachusetts']
# 4    POLYGON ((-109.05004 31.33250, -109.05017 31.4...     ['New Mexico']
# ..                                                 ...                ...
# 318  POLYGON ((-102.04224 36.99308, -102.05450 36.9...       ['Colorado']
# 319  MULTIPOLYGON (((-88.71072 30.25080, -88.65680 ...    ['Mississippi']
# 320  POLYGON ((-95.76565 40.58521, -95.75889 40.588...           ['Iowa']
# 321  MULTIPOLYGON (((-71.94356 41.28668, -71.92680 ...       ['New York']
# 322  MULTIPOLYGON (((-71.85957 41.32240, -71.86823 ...    ['Connecticut']
#
#                 type                  dish     region  \
# 0    General Cuisine  Arizona cheese crisp  Southwest
# 1    General Cuisine            Baked ziti  Northeast
# 2    General Cuisine        Borracho beans  Southwest
# 3    General Cuisine    Boston baked beans  Northeast
# 4    General Cuisine     Breakfast burrito  Southwest
# ..               ...                   ...        ...
# 318     Steak dishes               Slopper  Southwest
# 319     Steak dishes            Slugburger      South
# 320     Steak dishes        Steak de Burgo    Midwest
# 321     Steak dishes           Steak Diane  Northeast
# 322     Steak dishes  Steamed cheeseburger  Northeast
#
#                           city               sub-region             location  \
# 0                           []                       []              Arizona
# 1       ['New York, New York']                       []        New York City
# 2                           []                       []                Texas
# 3    ['Boston, Massachusetts']                       []        Massachusetts
# 4                           []                       []           New Mexico
# ..                         ...                      ...                  ...
# 318                         []                       []             Colorado
# 319                         []                       []          Mississippi
# 320       ['Des Moines, Iowa']                       []                 Iowa
# 321     ['New York, New York']                       []        New York City
# 322                         []  ['Central Connecticut']  Central Connecticut
#
#                                            description  \
# 0    An open-faced flour tortilla with grated chees...
# 1    A baked pasta casserole made of ziti, bechamel...
# 2    Pinto beans cooked with beef, pork or bacon, a...
# 3    A variety of baked beans, typically sweetened ...
# 4    A flour tortilla filled with breakfast items s...
# ..                                                 ...
# 318  A cheeseburger (or hamburger) served smothered...
# 319  A deep-fried patty containing beef or pork and...
# 320  Usually consists of abeef tenderloineither top...
# 321  Apan-friedbeefsteakwith a sauce made from the ...
# 322  Ground beef is steamed on a tray to create a j...
#
#                                              image_url  citations
# 0    https://upload.wikimedia.org/wikipedia/commons...        NaN
# 1    https://upload.wikimedia.org/wikipedia/commons...        NaN
# 2    https://upload.wikimedia.org/wikipedia/commons...        NaN
# 3    https://upload.wikimedia.org/wikipedia/commons...        NaN
# 4    https://upload.wikimedia.org/wikipedia/commons...        NaN
# ..                                                 ...        ...
# 318  https://upload.wikimedia.org/wikipedia/commons...        NaN
# 319  https://upload.wikimedia.org/wikipedia/commons...        NaN
# 320  https://upload.wikimedia.org/wikipedia/commons...        NaN
# 321  https://upload.wikimedia.org/wikipedia/commons...        NaN
# 322  https://upload.wikimedia.org/wikipedia/commons...        NaN
#
# [323 rows x 11 columns]

# %% [markdown]
# This gives me a gdf of many geometries of states, each with a corresponding food. But for my leaflet app, where I want a user to be able to click a state and get a list of foods from that state, I need to condense the foods into the (less than 50) states. How do I do this?
#
# for each row in the foods_with_geographies gpd, i need to loop through the states within the states column, and add each food (row) to an existing state in array format within an obj.
#
# Is it best to start over and do this in reverse from how I did it before? Taking the states_gdf and appending food info to it in a loop?

# %%
# this should have one state for every state in the states_geographies gdf
# create a new column that is an array of food properties
states_with_foods_obj_array = []
# loop through states with geographies
for index, state_with_geography in states_gdf.iterrows():
    # print(state_with_geography)
    # for every state_w_geo loop through foods. Check state column, loop through state array.
    # if food state matches geo_state, append to a new array within the state object
    new_state_with_geometry_and_foods_array = {
                    **state_with_geography,
                    'foods_array' : []
                }
    state_name_with_geography = state_with_geography['NAME']
    for index, food_row in foods_df.iterrows():
        state_name_array_from_foods = eval(food_row['state'].replace("’","'").replace("‘","'").replace('"',"'").replace('”',"'").replace('“',"'"))
        for state_name_from_food in state_name_array_from_foods:
            # print(state_name_from_food)
            # if state_name_from_food == state_name_with_geography, append food info obj to state obj
            if (state_name_from_food == state_name_with_geography):
                # print(food_row.state, state_name_with_geography)
                # print(state_with_geography, food_row)
                # create an object from state_geographies, with a food key with arr val that contains food_row objs
                # food_row_obj (type, dish, region, state, city, sub-region, location, description, image_url, citations)
                # state_geometry obj spread? where should this obj live? in top loop
                new_food_obj = {
                    'type': food_row.type,
                    'dish' : food_row.dish,
                    'region' : food_row.region,
                    'state' : food_row.state,
                    'city' : food_row.city,
                    'sub-region' : food_row['sub-region'],
                    'location' : food_row.location,
                    'description' : food_row.description,
                    'image_url' : food_row.image_url
                }
                # append new object to obj within state/geo loop
                new_state_with_geometry_and_foods_array['foods_array'].append(food_row)
    # append to main array (states_with_foods_obj_array)
    states_with_foods_obj_array.append(new_state_with_geometry_and_foods_array)

         
states_with_geographies_and_foods_gdf = gpd.GeoDataFrame(states_with_foods_obj_array, crs='4326')
states_with_geographies_and_foods_gdf.iloc[6].foods_array
# Out:
# [type                                             General Cuisine
#  dish                                                  Baked ziti
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A baked pasta casserole made of ziti, bechamel...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 3, dtype: object,
#  type                                             General Cuisine
#  dish                                                    Egg roll
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A cylindrical, savory roll with shredded cabba...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 17, dtype: object,
#  type                                             General Cuisine
#  dish                                             Pasta primavera
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description         Pasta in a cream sauce and fresh vegetables.
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 44, dtype: object,
#  type                                             General Cuisine
#  dish                                           Roasted chestnuts
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    Sold from pushcarts during New York City winte...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 51, dtype: object,
#  type                                             General Cuisine
#  dish                                     Spaghetti and meatballs
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A pasta dish made with spaghetti, tomato, and ...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 57, dtype: object,
#  type                                             General Cuisine
#  dish                                                Utica greens
#  region                                                 Northeast
#  state                                               [‘New York’]
#  city                                                          []
#  sub-region                                  ['Upstate New York']
#  location                                        Upstate New York
#  description    A dish made of hot peppers, sautéed greens, ch...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 63, dtype: object,
#  type                                                    Barbecue
#  dish                                               Garbage Plate
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                     ['Rochester, New York']
#  sub-region                                                    []
#  location                                                New York
#  description    A choice of two entrees such as cheeseburger, ...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 73, dtype: object,
#  type                                     Breads and bread dishes
#  dish                                        New York–style bagel
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    Bagels which are larger and fatter than other ...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 92, dtype: object,
#  type                                              Chicken dishes
#  dish                                               Buffalo wings
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                       ['Buffalo, New York']
#  sub-region                                                    []
#  location                                                New York
#  description    Chicken wing sections (wingettes and drumettes...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 101, dtype: object,
#  type                                              Chicken dishes
#  dish                                               Chicken Divan
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A chickencasseroleusually served with broccoli...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 104, dtype: object,
#  type                                              Chicken dishes
#  dish                                            Chicken Francese
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                                          []
#  sub-region                                                    []
#  location                                        New York (state)
#  description    An Italian-American dish of flour-dredged, egg...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 105, dtype: object,
#  type                                              Chicken dishes
#  dish                                            Chicken parmesan
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A breaded chicken breast covered in tomato sau...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 108, dtype: object,
#  type                                              Chicken dishes
#  dish                                             Chicken riggies
#  region                                                 Northeast
#  state                                               ['New York']
#  city                       [‘Utica, New York’, ‘Rome, New York’]
#  sub-region                                   ['Utica–Rome area']
#  location                                                New York
#  description    An Italian-American pasta dish of chicken,riga...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 109, dtype: object,
#  type                                              Chicken dishes
#  dish                                       General Tso's chicken
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A sweet and spicy Chinese-American deep-fried ...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 113, dtype: object,
#  type                                  Desserts and confectionery
#  dish                                                Baked Alaska
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A dish is made of ice cream placed in a pie di...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 121, dtype: object,
#  type                                  Desserts and confectionery
#  dish                                      Black and white cookie
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A round cookie with half chocolate half vanill...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 128, dtype: object,
#  type                                  Desserts and confectionery
#  dish                                               Blackout cake
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    Achocolate cakefilled with chocolate pudding a...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 129, dtype: object,
#  type                  Desserts and confectionery
#  dish                                      Cronut
#  region                                 Northeast
#  state                               ['New York']
#  city                      ['New York, New York']
#  sub-region                                    []
#  location                           New York City
#  description    A croissant crossed with a donut.
#  image_url                                    NaN
#  citations                                    NaN
#  Name: 140, dtype: object,
#  type                                  Desserts and confectionery
#  dish                                               New York roll
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A roll made from circular croissant dough, and...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 170, dtype: object,
#  type                                  Desserts and confectionery
#  dish                                   New York-style cheesecake
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description       Rich cheesecake made with a cream cheese base.
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 171, dtype: object,
#  type                                  Desserts and confectionery
#  dish                                                Pastry heart
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                       ['Buffalo, New York']
#  sub-region                                                    []
#  location                                                New York
#  description    A heart-shaped flaky puff pastry, similar to a...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 172, dtype: object,
#  type                                  Desserts and confectionery
#  dish                                      Strawberry rhubarb pie
#  region                                                 Northeast
#  state                                               [‘New York’]
#  city                                                          []
#  sub-region                   [‘Upstate New York’, ‘New England’]
#  location                                        Upstate New York
#  description    A sweet and tart pie made with straw berries a...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 184, dtype: object,
#  type                                     Fish and seafood dishes
#  dish                                         Lobster Fra Diavolo
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A pasta dish made with lobster, sometimes othe...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 208, dtype: object,
#  type                                     Fish and seafood dishes
#  dish                                             Lobster Newberg
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    An Americanseafooddish made from lobster, butt...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 209, dtype: object,
#  type                                     Fish and seafood dishes
#  dish                                       Lox and schmear bagel
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    Loxand cream cheese (schmear) on a New York-st...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 211, dtype: object,
#  type                                       Hot dogs and sausages
#  dish                                                   Bagel dog
#  region                                                  Multiple
#  state                           [‘New York’, ‘Illinois’, ‘Ohio’]
#  city           [‘New York, New York’, ‘Chicago, Illinois’, ‘C...
#  sub-region                                                    []
#  location                                              Cincinnati
#  description    A full-size or miniature hot dog, wrapped inba...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 225, dtype: object,
#  type                                       Hot dogs and sausages
#  dish                                            Michigan hot dog
#  region                                                 Northeast
#  state                                               [‘New York’]
#  city                                                          []
#  sub-region                   ['North Country of New York state']
#  location                         North Country of New York state
#  description    A natural-casing hot dog made of beef and pork...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 239, dtype: object,
#  type                                       Hot dogs and sausages
#  dish                                                   White hot
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                     ['Rochester, New York']
#  sub-region                                                    []
#  location                                                New York
#  description    A hot dog made with a combination of uncured a...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 248, dtype: object,
#  type                                                       Pizza
#  dish                                               Grandma pizza
#  region                                                 Northeast
#  state                                               [‘New York’]
#  city                                                          []
#  sub-region                                       ['Long Island']
#  location                                             Long Island
#  description    Thin-crust pizza topped sparingly with shredde...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 253, dtype: object,
#  type                                                       Pizza
#  dish                                        New York-style pizza
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    Pizza with a thin, hand-tossed crust that is s...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 256, dtype: object,
#  type                                               Potato dishes
#  dish                                            Potatoes O'Brien
#  region                                                 Northeast
#  state                              [‘Massachusetts’, ’New York']
#  city                                      [‘New York, New York’]
#  sub-region                                                    []
#  location                                                New York
#  description    Pan-friedpotatoes along with green and redbell...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 267, dtype: object,
#  type                                               Potato dishes
#  dish                                               Salt potatoes
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['Syracuse, New York']
#  sub-region                                                    []
#  location                                                New York
#  description    As the potatoes cook, the salty water forms a ...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 268, dtype: object,
#  type                                                 Rice dishes
#  dish                                             Halal over rice
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    Halal-slaughtered lamb or chicken overyellow r...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 271, dtype: object,
#  type                                                      Salads
#  dish                                               Waldorf salad
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    First created between 1893 and 1896 at the Wal...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 291, dtype: object,
#  type                                                      Salads
#  dish                                             Whitefish salad
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A salad of smoked freshwater whitefish and may...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 292, dtype: object,
#  type                                                  Sandwiches
#  dish                                        Bacon egg and cheese
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A sandwich made with bacon, eggs (usually frie...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 293, dtype: object,
#  type                                                  Sandwiches
#  dish                                                Beef on weck
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                       ['Buffalo, New York']
#  sub-region                                                    []
#  location                                                New York
#  description    Thin-sliced roast beef on a Kümmelweck roll (a...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 295, dtype: object,
#  type                                                  Sandwiches
#  dish                                              Chopped Cheese
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    Ground beef with onions and often green bell p...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 296, dtype: object,
#  type                                                  Sandwiches
#  dish                                               Club sandwich
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                                          []
#  sub-region                                                    []
#  location                                        New York (state)
#  description    A three-layer sandwich consisting of three sli...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 298, dtype: object,
#  type                                                  Sandwiches
#  dish                                               Eggs Benedict
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    The two halves of a toasted English muffintopp...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 301, dtype: object,
#  type                                                  Sandwiches
#  dish                                             Pastrami on rye
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    Pastrami on rye bread, typically with spicy br...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 315, dtype: object,
#  type                                                  Sandwiches
#  dish                                                     Spiedie
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                    [‘Binghamton, New York’]
#  sub-region                                                    []
#  location                                                New York
#  description    A spiedie (/ˈspiːdi/SPEE-dee) is a sandwich of...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 327, dtype: object,
#  type                                             Soups and stews
#  dish                                Manhattan-style clam chowder
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    Clams cooked in a redbrothwith tomatoes for fl...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 343, dtype: object,
#  type                                             Soups and stews
#  dish                                            Matzah ball soup
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    Staple food on Passover. The Matzah balldumpli...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 345, dtype: object,
#  type                                             Soups and stews
#  dish                                                 Vichyssoise
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    Vichyssoise (/viːʃiːˈswɑːz/vee-shee-SWAHZ) is ...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 353, dtype: object,
#  type                                                Steak dishes
#  dish                                             Delmonico steak
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A method of preparation from one of several cu...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 359, dtype: object,
#  type                                                Steak dishes
#  dish                                                    Negimaki
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    A Japanese-American food consisting of broiled...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 364, dtype: object,
#  type                                                Steak dishes
#  dish                                                 Steak Diane
#  region                                                 Northeast
#  state                                               ['New York']
#  city                                      ['New York, New York']
#  sub-region                                                    []
#  location                                           New York City
#  description    Apan-friedbeefsteakwith a sauce made from the ...
#  image_url      https://upload.wikimedia.org/wikipedia/commons...
#  citations                                                    NaN
#  Name: 372, dtype: object]
